# %% [markdown]
# ## Image Reading

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
img = '/content/drive/MyDrive/Mestrado/Disciplinas/lenna.png'
image = imread(img)

# %%
image.size, image.shape, image.ndim
# Out:
# (786432, (512, 512, 3), 3)

# %%
def norm(im : np.ndarray):
  min, max = 0, 255
  norm_img = np.dot(im[::,:3], [255.0, 255.0 , 255.0])
  imag = np.clip(norm_img, min, max)

  return imag

# %%
r = image[:,:,0]
g = image[:,:,1]
b = image[:,:,2]

# %%
f, (x1, x2, x3) = plt.subplots(1, 3, figsize = (10,5))
x1.imshow(r, cmap='gray')
x2.imshow(g, cmap='gray')
x3.imshow(b, cmap='gray')

# %% [markdown]
# ## OpenCV Lib
# Convert RGB to HSV

# %%
import cv2

# %%
img = cv2.imread(img)
#Diretório original da imagem

# %%
img
# Out:
# array([[[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        [[125, 137, 226],
#         [125, 137, 226],
#         [133, 137, 223],
#         ...,
#         [122, 148, 230],
#         [110, 130, 221],
#         [ 90,  99, 200]],
#
#        ...,
#
#        [[ 60,  18,  84],
#         [ 60,  18,  84],
#         [ 58,  27,  92],
#         ...,
#         [ 84,  73, 173],
#         [ 76,  68, 172],
#         [ 79,  62, 177]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]],
#
#        [[ 57,  22,  82],
#         [ 57,  22,  82],
#         [ 62,  32,  96],
#         ...,
#         [ 79,  70, 179],
#         [ 81,  71, 181],
#         [ 81,  74, 185]]], dtype=uint8)

# %%
image_1 = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
image_2 = cv2.cvtColor(image_1, cv2.COLOR_RGB2HSV)

# %%
f, (im1, im2) = plt.subplots(1,2, figsize=(10,5))
im1.imshow(image_1)
im1.set_title('RGB_Scale')
im2.imshow(image_2)
im2.set_title('HSV_Scale')
# Out:
# Text(0.5, 1.0, 'HSV_Scale')

# %% [markdown]
# A escala HSV é pode ser interpretada como um vetor com as seguintes características:\
#
# $\quad$ H: Hue Color | Ângulo em graus $\in [ 0,360]$  \
# $\quad$ S: Saturação $\in [0,1]$\
# $\quad$ V: Valor $\in [0,1]$
#
# $V = max = max(R, G, B), \qquad min(R, G, B)$\
# $S = \frac{(max-min)}{max} \qquad (\text{ou } S = 0, \text{ se } V = 0)$\
# $\quad \textbf{Se }(max = R):$\
# $H = 60 \times (G-B)$\
# $\quad \textbf{Se }(max = G):$\
# $H = 60 \times [2+(B-R)]$\
# $\quad \textbf{Se }(max = B):$\
# $H = 60 \times [4+(R-G)]$\
# $\quad \textbf{Se }(H < 0):$\
# $H = H + 360$

# %% [markdown]
# ## Variação de escalas de Cinza

# %%
def vary_grayscale(image, factor):

    grayscale_image = np.dot(image[...,:3], [0.2989, 0.5870, 0.1140])

    varied_image = grayscale_image * factor
    varied_image = np.clip(varied_image, 0, 255)
    varied_image = varied_image.astype(np.uint8)

    return varied_image

# %%
img = '/content/drive/MyDrive/Mestrado/Disciplinas/lenna.png'
image = plt.imread(img)

fig, ax = plt.subplots(1,10, figsize=(30,500))
k = 0

fator = np.linspace(1.0,10.0,num=10)

for i in fator:
  factor = i
  varied_image = vary_grayscale(image, factor)

  plt.figure(figsize=(10, 5))
  ax[k].imshow(varied_image, cmap='gray')

  k += 1 #Iterador do plot

plt.show()

# %% [markdown]
# ##Variação de Escala

# %%
def downsampling(im : np.ndarray, skip):
  return image[::skip,::skip]

# Carregar a imagem usando plt.imread
img = '/content/drive/MyDrive/Mestrado/Disciplinas/lenna.png'
image = plt.imread(img)
image_resized = downsampling(image,16)

fig, (m,n) = plt.subplots(1,2, figsize=(10,20))
m.axis("off"), n.axis("off")

m.imshow(image)
n.imshow(image_resized)
